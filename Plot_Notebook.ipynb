# %%
import sys
sys.path.append('./src')

from plot_tools import PlotTools

# Initialize PlotTools
plot_tools = PlotTools(plot_dir='../plots')

# Generate plots from the JSON file
json_path = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json'  
plots = plot_tools.draw_plots(json_path)

# Display the generated plots
for plot in plots:
    from IPython.display import Image
    display(Image(filename=plot))
